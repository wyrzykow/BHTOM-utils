# %% [markdown]
# <a href="https://colab.research.google.com/github/wyrzykow/BHTOM-utils/blob/main/BHTOM_for_Staszek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #BHTOM newletter for CDK-500 Krakow telescope

# %%
# !pip install astroplan
# Out:
# Requirement already satisfied: astroplan in /usr/local/lib/python3.10/dist-packages (0.10)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from astroplan) (1.25.2)
# Requirement already satisfied: astropy>=4 in /usr/local/lib/python3.10/dist-packages (from astroplan) (5.3.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from astroplan) (2023.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from astroplan) (1.16.0)
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=4->astroplan) (2.0.1.4)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy>=4->astroplan) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=4->astroplan) (24.0)

# %%
from astropy.coordinates import get_body, SkyCoord
from astropy import units
from astropy.time import Time
from astroplan import Observer, FixedTarget, time_grid_from_range
import numpy as np
from datetime import datetime, timedelta, date

# %%
#SETUP
send_email=True

#telescope setup:
site_details = {'sitecode': 'Krakow', 'latitude': 50.05, 'longitude': 19.82, 'elevation': 300}
camera_name = "OAUJ-CDK500_U47" ##TODO: what if two cameras are used? #OAUJ-CDK500_U47 , OAUJ-CDK500_F42
mag_limit = 17.0
dec_limit = -30
destination_email = "staszek.zola@gmail.com"

# %%
#visibility parameters:
start_time = datetime.now()

airmass_limit = 2.5
length=2 #in days
interval=60 #in minutes between samplings
observer = Observer(longitude=site_details.get('longitude')*units.deg,
                    latitude=site_details.get('latitude')*units.deg,
                    elevation=site_details.get('elevation')*units.m)

# %%
#BHTOM token
from google.colab import userdata
auth_token=userdata.get('bhtomtoken')

# %%
def get_astroplan_sun_and_time(start_time, end_time, interval):
    """
    Uses astroplan's time_grid_from_range to generate
    an astropy Time object covering the time range.

    Uses astropy's get_sun to generate sun positions over
    that time range.

    If time range is small and interval is coarse, approximates
    the sun at a fixed position from the middle of the
    time range to speed up calculations.
    Since the sun moves ~4 minutes a day, this approximation
    happens when the number of days covered by the time range
    * 4 is less than the interval (in minutes) / 2.

    :param start_time: start of the window for which to calculate the airmass
    :type start_time: datetime

    :param end_time: end of the window for which to calculate the airmass
    :type end_time: datetime

    :param interval: time interval, in minutes, at which to calculate airmass within the given window
    :type interval: int

    :returns: ra/dec positions of the sun over the time range,
        time range between start_time and end_time at interval
    :rtype: astropy SkyCoord, astropy Time
    """

    start = Time(start_time)
    end = Time(end_time)

    time_range = time_grid_from_range(time_range=[start, end], time_resolution=interval*units.minute)

    number_of_days = end.mjd - start.mjd
    if number_of_days*4 < float(interval)/2:
        # Hack to speed up calculation by factor of ~3
        sun_coords = get_body("sun",time_range[int(len(time_range)/2)])
        sun = FixedTarget(name='sun', coord=SkyCoord(sun_coords.ra, sun_coords.dec, unit='deg'))
    else:
        sun = get_body("sun", time_range)

    return sun, time_range

# %%
#for a given target and observatory, returns true if the object is visible in the period provided
def check_visibility(name, ra, dec, observer, start_time, length=2, interval=60, airmass_limit=2.5):
  body = FixedTarget(name=name, coord=SkyCoord(ra, dec, unit='deg'))

  end_time = start_time + timedelta(days=length)

  visibility = {}
  sun, time_range = get_astroplan_sun_and_time(start_time, end_time, interval)
  sun_alt = observer.altaz(time_range, sun).alt
  obj_airmass = observer.altaz(time_range, body).secz

  bad_indices = np.argwhere(
      (obj_airmass >= airmass_limit) |
      (obj_airmass <= 1) |
      (sun_alt > -12*units.deg)  # between astronomical twilights, i.e. sun is up
  )

  obj_airmass = [None if i in bad_indices else float(airmass) for i, airmass in enumerate(obj_airmass)]

  # Check if all elements in obj_airmass are None
  if all(i is None for i in obj_airmass):
#      print("The list obj_airmass is full of None values.")
      return False
  else:
#      print("The list obj_airmass contains non-None values.")
      return True

# %%
# name="Gaia24bfe"
# ra,dec=311.33472,-17.57744

# check_visibility(name, ra, dec, observer, start_time)

# %%
import requests
import pandas as pd
import json
from datetime import datetime, timedelta
import pytz

from IPython.display import display, HTML

# %%
 #asking for ALL targets, as for now, API does not allow for filtering on importance
request_body = {
         "decMin": dec_limit

    }

# Define headers
headers = {
    'accept': 'application/json',
    'Authorization': f'Token {auth_token}',  ## you can hard-code your token here as well
    'Content-Type': 'application/json',
    'X-CSRFToken': 'uUz2fRnXhPuvD9YuuiDW9cD1LsajeaQnE4hwtEAfR00SgV9bD5HCe5i8n4m4KcOr'
}
api_url =  "https://bh-tom2.astrolabs.pl/targets/getTargetList/"

# Send the POST request
response = requests.post(api_url, json=request_body, headers=headers)
data_json = json.loads(response.text)
data = json.loads(data_json)
data_list = [item['fields'] for item in data]
df = pd.DataFrame(data_list)

#print(df)

# %%
df.columns
# Out:
# Index(['name', 'type', 'created', 'modified', 'ra', 'dec', 'epoch', 'parallax',
#        'pm_ra', 'pm_dec', 'galactic_lng', 'galactic_lat', 'distance',
#        'distance_err', 'scheme', 'epoch_of_elements', 'mean_anomaly',
#        'arg_of_perihelion', 'eccentricity', 'lng_asc_node', 'inclination',
#        'mean_daily_motion', 'semimajor_axis', 'epoch_of_perihelion',
#        'ephemeris_period', 'ephemeris_period_err', 'ephemeris_epoch',
#        'ephemeris_epoch_err', 'perihdist', 'classification', 'discovery_date',
#        'mjd_last', 'mag_last', 'importance', 'cadence', 'priority',
#        'sun_separation', 'creation_date', 'constellation', 'dont_update_me',
#        'phot_class', 'photometry_plot', 'photometry_plot_obs',
#        'photometry_icon_plot', 'spectroscopy_plot', 'data_plot', 'filter_last',
#        'cadence_priority', 'description'],
#       dtype='object')

# %%
#filtering on importance and sundistance

df1 = df[(df.importance >= 1) & (df.sun_separation > 50) & (df.mag_last<mag_limit)].copy().reset_index(drop=True)

print(len(df1))
# Out:
# 40

# %%
current_date = datetime.now(pytz.UTC)
formatted_date = current_date.strftime("%d %B, %Y")

# %%
## Selection of targets:
# limit the list to visible now
visibility_results = []

# Iterate over DataFrame rows
for index, row in df1.iterrows():
    # Apply check_visibility function and append result to list
    visibility_result = check_visibility(row['name'], row['ra'], row['dec'], observer, start_time)
    visibility_results.append(visibility_result)

# Add results as a new column to the DataFrame
df1['visibility'] = visibility_results
df_visible = df1[df1['visibility'] == True]
# 27   None  ...                        --
# 28   None  ...                        --
# 29   None  ...  Main Sequence Star 99.6%
# 30   None  ...           Red Giant 94.8%
#
#                                       photometry_plot  \
# 0               /plots/photometry/Gaia23crr_plot.json
# 1            /plots/photometry/ZTF18aarippg_plot.json
# 2               /plots/photometry/Gaia23cpd_plot.json
# 3               /plots/photometry/Gaia18bad_plot.json
# 4               /plots/photometry/Gaia21asp_plot.json
# 5               /plots/photometry/Gaia23bsf_plot.json
# 6               /plots/photometry/B1721+343_plot.json
# 7                  /plots/photometry/RZ_LMi_plot.json
# 8                /plots/photometry/V374_Peg_plot.json
# 9              /plots/photometry/8C0716_714_plot.json
# 10                   /plots/photometry/TCrB_plot.json
# 11              /plots/photometry/Gaia23dfy_plot.json
# 12        /plots/photometry/NGC5683-Seyfert_plot.json
# 13  /plots/photometry/SDSS_J154329.47+335908.6_plo...
# 14              /plots/photometry/Gaia24alm_plot.json
# 15              /plots/photometry/Gaia24azc_plot.json
# 16              /plots/photometry/Gaia24ayd_plot.json
# 17              /plots/photometry/Gaia24bfe_plot.json
# 18                 /plots/photometry/AR UMa_plot.json
# 19              /plots/photometry/4U0115+63_plot.json
# 20        /plots/photometry/SAXJ2103.5+4545_plot.json
# 21             /plots/photometry/KS1947+300_plot.json
# 22         /plots/photometry/IGRJ21343+4738_plot.json
# 23              /plots/photometry/2S0114+65_plot.json
# 24            /plots/photometry/GROJ2058+42_plot.json
# 25              /plots/photometry/4U2206+54_plot.json
# 26              /plots/photometry/AT2024hcr_plot.json
# 27             /plots/photometry/SN 2024igg_plot.json
# 28              /plots/photometry/Gaia24avs_plot.json
# 29             /plots/photometry/TabbysStar_plot.json
# 30           /plots/photometry/ZTF23aaqazhf_plot.json
#
#                                   photometry_plot_obs  \
# 0           /plots/photometry/obs_Gaia23crr_plot.json
# 1        /plots/photometry/obs_ZTF18aarippg_plot.json
# 2           /plots/photometry/obs_Gaia23cpd_plot.json
# 3           /plots/photometry/obs_Gaia18bad_plot.json
# 4           /plots/photometry/obs_Gaia21asp_plot.json
# 5           /plots/photometry/obs_Gaia23bsf_plot.json
# 6           /plots/photometry/obs_B1721+343_plot.json
# 7              /plots/photometry/obs_RZ_LMi_plot.json
# 8            /plots/photometry/obs_V374_Peg_plot.json
# 9          /plots/photometry/obs_8C0716_714_plot.json
# 10               /plots/photometry/obs_TCrB_plot.json
# 11          /plots/photometry/obs_Gaia23dfy_plot.json
# 12    /plots/photometry/obs_NGC5683-Seyfert_plot.json
# 13  /plots/photometry/obs_SDSS_J154329.47+335908.6...
# 14          /plots/photometry/obs_Gaia24alm_plot.json
# 15          /plots/photometry/obs_Gaia24azc_plot.json
# 16          /plots/photometry/obs_Gaia24ayd_plot.json
# 17          /plots/photometry/obs_Gaia24bfe_plot.json
# 18             /plots/photometry/obs_AR UMa_plot.json
# 19          /plots/photometry/obs_4U0115+63_plot.json
# 20    /plots/photometry/obs_SAXJ2103.5+4545_plot.json
# 21         /plots/photometry/obs_KS1947+300_plot.json
# 22     /plots/photometry/obs_IGRJ21343+4738_plot.json
# 23          /plots/photometry/obs_2S0114+65_plot.json
# 24        /plots/photometry/obs_GROJ2058+42_plot.json
# 25          /plots/photometry/obs_4U2206+54_plot.json
# 26          /plots/photometry/obs_AT2024hcr_plot.json
# 27         /plots/photometry/obs_SN 2024igg_plot.json
# 28          /plots/photometry/obs_Gaia24avs_plot.json
# 29         /plots/photometry/obs_TabbysStar_plot.json
# 30       /plots/photometry/obs_ZTF23aaqazhf_plot.json
#
#                                  photometry_icon_plot spectroscopy_plot  \
# 0           /plots/photometryIcon/Gaia23crr_plot.json
# 1        /plots/photometryIcon/ZTF18aarippg_plot.json
# 2           /plots/photometryIcon/Gaia23cpd_plot.json
# 3           /plots/photometryIcon/Gaia18bad_plot.json
# 4           /plots/photometryIcon/Gaia21asp_plot.json
# 5           /plots/photometryIcon/Gaia23bsf_plot.json
# 6           /plots/photometryIcon/B1721+343_plot.json
# 7              /plots/photometryIcon/RZ_LMi_plot.json
# 8            /plots/photometryIcon/V374_Peg_plot.json
# 9          /plots/photometryIcon/8C0716_714_plot.json
# 10               /plots/photometryIcon/TCrB_plot.json
# 11          /plots/photometryIcon/Gaia23dfy_plot.json
# 12    /plots/photometryIcon/NGC5683-Seyfert_plot.json
# 13  /plots/photometryIcon/SDSS_J154329.47+335908.6...
# 14          /plots/photometryIcon/Gaia24alm_plot.json
# 15          /plots/photometryIcon/Gaia24azc_plot.json
# 16          /plots/photometryIcon/Gaia24ayd_plot.json
# 17          /plots/photometryIcon/Gaia24bfe_plot.json
# 18             /plots/photometryIcon/AR UMa_plot.json
# 19          /plots/photometryIcon/4U0115+63_plot.json
# 20    /plots/photometryIcon/SAXJ2103.5+4545_plot.json
# 21         /plots/photometryIcon/KS1947+300_plot.json
# 22     /plots/photometryIcon/IGRJ21343+4738_plot.json
# 23          /plots/photometryIcon/2S0114+65_plot.json
# 24        /plots/photometryIcon/GROJ2058+42_plot.json
# 25          /plots/photometryIcon/4U2206+54_plot.json
# 26          /plots/photometryIcon/AT2024hcr_plot.json
# 27         /plots/photometryIcon/SN 2024igg_plot.json
# 28          /plots/photometryIcon/Gaia24avs_plot.json
# 29         /plots/photometryIcon/TabbysStar_plot.json
# 30       /plots/photometryIcon/ZTF23aaqazhf_plot.json
#
#    data_plot filter_last cadence_priority  \
# 0       None    ATLAS(o)              0.0
# 1       None    ATLAS(o)             19.8
# 2       None    ATLAS(o)             10.8
# 3       None          ~G              5.8
# 4       None    ATLAS(o)              0.1
# 5       None    ATLAS(o)              9.7
# 6       None    ATLAS(o)              0.1
# 7       None    ATLAS(o)             21.4
# 8       None    ATLAS(o)              4.0
# 9       None   R(GaiaSP)            374.2
# 10      None    ATLAS(o)             36.6
# 11      None    ATLAS(o)              6.6
# 12      None    ATLAS(o)             29.9
# 13      None    ATLAS(o)              3.8
# 14      None          ~G             15.3
# 15      None    ATLAS(o)              8.7
# 16      None      Gaia/r             12.7
# 17      None      Gaia/r              5.0
# 18      None    ATLAS(o)             17.0
# 19      None    ATLAS(o)             32.5
# 20      None    ATLAS(o)              0.3
# 21      None    ATLAS(o)              0.3
# 22      None    ATLAS(o)              0.3
# 23      None          ~G             16.2
# 24      None    ATLAS(o)              0.3
# 25      None    ATLAS(o)              1.2
# 26      None    ATLAS(o)              9.1
# 27      None    ATLAS(o)              6.1
# 28      None   R(GaiaSP)       -2399976.3
# 29      None    ATLAS(o)             24.7
# 30      None          ~G             15.6
#
#                                           description visibility
# 0                          candidate Be-star outburst       True
# 1   Tick-Tok possibly merging Super Massive Black ...       True
# 2   potential long and bright microlensing event o...       True
# 3                                             unknown       True
# 4   unknown slowly rising object, probably Be-type...       True
# 5                                slowly rising object       True
# 6                                         A giant QSO       True
# 7                                                None       True
# 8                                                None       True
# 9                  high cadence variability suspected       True
# 10       recurent nova predicted to explode 2024/2025       True
# 11                       candidate microlensing event       True
# 12  active nucleus of a nearby galaxy for frequent...       True
# 13                       candidate lensed QSO from AI       True
# 14  candidate bright microlensing event on the ris...       True
# 15  bright gal.plane source candidate microlensing...       True
# 16            bright candidate for microlensing event       True
# 17                       candidate microlensing event       True
# 18                                               None       True
# 19                                    Be X-ray binary       True
# 20                                    Be X-ray binary       True
# 21                                    Be X-ray binary       True
# 22                                    Be X-ray binary       True
# 23                            Supergiant X-ray binary       True
# 24                                    Be X-ray binary       True
# 25                                    Be X-ray binary       True
# 26  candidate microlensing events from Chinese KAT...       True
# 27                               Astro-COLIBRI target       True
# 28                                    Confirmed SN II       True
# 29  Boyajian's Star, WTF Star, KIC 8462852, weird ...       True
# 30  potential microlensing event from FINK, KATS24...       True
#
# [31 rows x 50 columns]

# %%
#asking for ALL dataproducts from this telescope

from datetime import datetime
from dateutil.relativedelta import relativedelta

# Get the current date and time
now = datetime.now()

start_date = "2023-01-01T00:00:00.00+00:00"

request_body = {
#    "created_start": week_ago_str
    "created_start": start_date,
    "camera": camera_name
}

# Define headers
headers = {
    'accept': 'application/json',
    'Authorization': f'Token {auth_token}',  ## you can hard-code your token here as well
    'Content-Type': 'application/json',
    'X-CSRFToken': 'uUz2fRnXhPuvD9YuuiDW9cD1LsajeaQnE4hwtEAfR00SgV9bD5HCe5i8n4m4KcOr'
}
api_url =  "https://bh-tom2.astrolabs.pl/common/api/data/"

response = requests.post(api_url, json=request_body, headers=headers)
data_json = json.loads(response.text)
df_data = pd.DataFrame(data_json)

# %%
#removing Dry Runs
df_data.drop(df_data[df_data['dryRun'] == True].index, inplace=True)

df_data.columns
# Out:
# Index(['id', 'user_name', 'target_name', 'target', 'user', 'camera',
#        'observatory_name', 'observatory', 'product_id', 'data', 'status',
#        'photometry_data', 'fits_data', 'extra_data', 'created', 'modified',
#        'data_product_type', 'featured', 'thumbnail', 'dryRun', 'comment',
#        'observation_record', 'group'],
#       dtype='object')

# %%
total_fits = len(df_data)
total_fits
# Out:
# 449

# %%
#Last week's yield:
df_data['created'] = pd.to_datetime(df_data['created'])
one_week_ago = datetime.now(pytz.UTC) - timedelta(weeks=1)
df_data_last_week = df_data[df_data['created'] > one_week_ago]
last_week_counts = len(df_data_last_week)
last_week_counts
# Out:
# 6

# %%
#Last week's success rate:
# Get counts of each status
status_counts = df_data_last_week['status'].value_counts()

# Print counts
print(status_counts)

# Count for success statuses
success_count = status_counts.get('S', 0)
print(f'Success count: {success_count}')

# Count for error statuses
error_count = status_counts.get('E', 0)
print(f'Error count: {error_count}')

# Count for other statuses
other_count = status_counts.sum() - success_count - error_count
print(f'Other statuses count: {other_count}')
# Out:
# status
# P    4
# E    2
# Name: count, dtype: int64
# Success count: 0
# Error count: 2
# Other statuses count: 4

# %%
#Extracting a list of targets observed with this telescope ever

unique_targets = df_data['target_name'].value_counts()

unique_targets
# Out:
# target_name
# SN2023ixf    291
# Gaia23crr     76
# TCrB          47
# Gaia23dai     29
# Gaia24ayd      6
# Name: count, dtype: int64

# %%
#Scoring system:
# name contains Gaia = +5
# phot_class contains Ulens or Red Giant = +5
# description contains microlensing = +5
# classification contains Microlensing = +5
# description contains COLIBRI = +2
# description contains nova = +2
#
# AND +10 if the target was already observed with this telescope

def score(row):
    points = row['importance']
    if row['name'] and 'Gaia' in row['name']:
        points += 5
    if row['phot_class'] and ('Ulens' in row['phot_class'] or 'Red Giant' in row['phot_class']):
        points += 3
    if row['description'] and 'microlensing' in row['description']:
        points += 5
    if row['classification'] and 'Microlensing' in row['classification']:
        points += 5
    if row['description'] and 'COLIBRI' in row['description']:
        points += 2
    if row['description'] and 'nova' in row['description']:
        points += 2
    if row['name'] in unique_targets:
        points +=100
    return points

df_visible['score'] = df_visible.apply(score, axis=1)

df_sorted = df_visible.sort_values('score', ascending=False)
#df_sorted

# %%
from astropy.coordinates import SkyCoord
import astropy.units as u

def convert_ra_to_hex(row):
    c = SkyCoord(ra=row['ra']*u.degree, dec=row['dec']*u.degree, frame='icrs')
    ra_hms = c.ra.to_string(u.hourangle, sep=":", precision=2)
    return ra_hms

df_sorted['ra_hex'] = df_sorted.apply(convert_ra_to_hex, axis=1)

def convert_dec_to_sex(row):
    c = SkyCoord(ra=row['ra']*u.degree, dec=row['dec']*u.degree, frame='icrs')
    dec_dms = c.dec.to_string(u.degree, sep=":", alwayssign=True, precision=2)
    return dec_dms

df_sorted['dec_hex'] = df_sorted.apply(convert_dec_to_sex, axis=1)

#df_sorted

# %%
#OUTPUTING all target found:
from astropy.coordinates import SkyCoord
import astropy.units as u

# Selecting the required columns
df_selected = df_sorted[['name', 'ra_hex', 'dec_hex', 'mag_last', 'sun_separation', 'classification', 'description', 'score']]

# Define a function to format the strings
def make_hyperlink(name):
    return '<a href="https://bh-tom2.astrolabs.pl/targets/{0}/">{0}</a>'.format(name)

df_selected = df_selected.copy()
df_selected.loc[:, 'name'] = df_selected['name'].apply(make_hyperlink)

# Convert the DataFrame to HTML and escape=False to render HTML tags
html_table = df_selected.to_html(index=False, escape=False)
# Remove border by replacing <table> with <table border="0">
html_table = html_table.replace('<table', '<table border="0"')

# %% [markdown]
# #formating the email

# %%
# Creating the email message
email_message = f"""
Hello {camera_name},
<p>
Greetings from the BHTOM Automated Target Selector!
</p>
<p>

</p>
<p>
Date: {formatted_date}<br>
Targets for you (importance>=1, mag_limit {mag_limit}, visible now, you observed it already are at the top)</p>
<p>
{html_table}
</p>
<hr>
<p>
<b>Last week's count {last_week_counts} ({success_count} with success).</b>
<br>Your observatory collected in total: {total_fits} - thank you!
<hr>
Clear skies!
<br>
Your BHTOM Team
<br>
<a href="https://bhtom.space">bhtom.space</a>
</p>
"""

# %%
(email_message)
# Out:
# '\nHello OAUJ-CDK500_U47,\n<p>\nGreetings from the BHTOM Automated Target Selector!\n</p>\n<p>\n\n</p>\n<p>\nDate: 05 June, 2024<br>\nTargets for you (importance>=1, mag_limit 17.0, visible now, you observed it already are at the top)</p>\n<p>\n<table border="0" border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>name</th>\n      <th>ra_hex</th>\n      <th>dec_hex</th>\n      <th>mag_last</th>\n      <th>sun_separation</th>\n      <th>classification</th>\n      <th>description</th>\n      <th>score</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia24ayd/">Gaia24ayd</a></td>\n      <td>20:03:18.02</td>\n      <td>+30:39:04.54</td>\n      <td>13.2</td>\n      <td>110.0</td>\n      <td>Unknown</td>\n      <td>bright candidate for microlensing event</td>\n      <td>120.0</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/TCrB/">TCrB</a></td>\n      <td>15:59:30.16</td>\n      <td>+25:55:12.61</td>\n      <td>10.2</td>\n      <td>130.0</td>\n      <td>Nova</td>\n      <td>recurent nova predicted to explode 2024/2025</td>\n      <td>115.0</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia23crr/">Gaia23crr</a></td>\n      <td>19:52:29.57</td>\n      <td>+29:26:37.28</td>\n      <td>12.6</td>\n      <td>112.0</td>\n      <td>Be-star outburst</td>\n      <td>candidate Be-star outburst</td>\n      <td>106.0</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia23cpd/">Gaia23cpd</a></td>\n      <td>19:10:08.82</td>\n      <td>-4:43:14.74</td>\n      <td>15.1</td>\n      <td>142.0</td>\n      <td>Microlensing Event</td>\n      <td>potential long and bright microlensing event or weird variable</td>\n      <td>24.0</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia24bfe/">Gaia24bfe</a></td>\n      <td>20:45:20.33</td>\n      <td>+27:34:38.78</td>\n      <td>16.7</td>\n      <td>105.0</td>\n      <td>Unknown</td>\n      <td>candidate microlensing event</td>\n      <td>20.0</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia23dfy/">Gaia23dfy</a></td>\n      <td>18:47:41.43</td>\n      <td>+9:02:38.29</td>\n      <td>16.5</td>\n      <td>138.0</td>\n      <td>Unknown</td>\n      <td>candidate microlensing event</td>\n      <td>20.0</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia24azc/">Gaia24azc</a></td>\n      <td>19:44:48.53</td>\n      <td>+23:37:50.88</td>\n      <td>14.8</td>\n      <td>118.0</td>\n      <td>Unknown</td>\n      <td>bright gal.plane source candidate microlensing event or Be-type outburst</td>\n      <td>20.0</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia24alm/">Gaia24alm</a></td>\n      <td>22:45:19.16</td>\n      <td>+60:55:08.76</td>\n      <td>16.0</td>\n      <td>71.0</td>\n      <td>Unknown</td>\n      <td>candidate bright microlensing event on the rise or Be star</td>\n      <td>18.0</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/ZTF23aaqazhf/">ZTF23aaqazhf</a></td>\n      <td>19:01:32.48</td>\n      <td>+22:36:53.91</td>\n      <td>15.3</td>\n      <td>125.0</td>\n      <td>Unknown</td>\n      <td>potential microlensing event from FINK, KATS24K002</td>\n      <td>16.0</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/AT2024hcr/">AT2024hcr</a></td>\n      <td>18:17:34.80</td>\n      <td>-7:42:55.40</td>\n      <td>16.5</td>\n      <td>155.0</td>\n      <td>Microlensing Event</td>\n      <td>candidate microlensing events from Chinese KATS survey, AT 2024hcr = ZTF24aahkoms = KATS24H004, emailed by Wenjie Zhou</td>\n      <td>15.0</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia18bad/">Gaia18bad</a></td>\n      <td>22:07:03.59</td>\n      <td>+5:53:24.00</td>\n      < ...

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from getpass import getpass

if send_email:
  # Set up the SMTP server
  # Set up the SMTP server
  s = smtplib.SMTP(host='smtp.gmail.com', port=587)
  s.starttls()

  # Login to your Gmail account
  password = 'ggzr clob tbcm ehtc'
  s.login('wyrzykow@gmail.com', password)

  # Create a message
  msg = MIMEMultipart()  # create a message

  # Setup the parameters of the message
  msg['From']="wyrzykow@gmail.com"
  msg['To']=destination_email
  msg['Subject']=f"BHTOM Targets for {formatted_date} for {camera_name}"

  msg.attach(MIMEText(email_message, 'html'))

  # Send the message via the server set up earlier.
  s.send_message(msg)

  # Terminate the SMTP session and close the connection
  s.quit()

# %%
### Separate code for BHTOM webpage:
# recently observed events - target names
# one-year statistics: winners per users

# %%
display(HTML(email_message))
# Out:
# Hello OAUJ-CDK500_U47,
# <p>
# Greetings from the BHTOM Automated Target Selector!
# </p>
# <p>
#
# </p>
# <p>
# Date: 05 June, 2024<br>
# Targets for you (importance>=1, mag_limit 17.0, visible now, you observed it already are at the top)</p>
# <p>
# <table border="0" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>ra_hex</th>
#       <th>dec_hex</th>
#       <th>mag_last</th>
#       <th>sun_separation</th>
#       <th>classification</th>
#       <th>description</th>
#       <th>score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets