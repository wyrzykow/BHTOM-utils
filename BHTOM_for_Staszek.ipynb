# %% [markdown]
# <a href="https://colab.research.google.com/github/wyrzykow/BHTOM-utils/blob/main/BHTOM_for_Staszek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #BHTOM newletter for CDK-500 Krakow telescope

# %%
# !pip install astroplan
# Out:
# Collecting astroplan
#   Downloading astroplan-0.10.tar.gz (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 kB 2.6 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from astroplan) (1.25.2)
# Requirement already satisfied: astropy>=4 in /usr/local/lib/python3.10/dist-packages (from astroplan) (5.3.4)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from astroplan) (2023.4)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from astroplan) (1.16.0)
# Requirement already satisfied: pyerfa>=2.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=4->astroplan) (2.0.1.4)
# Requirement already satisfied: PyYAML>=3.13 in /usr/local/lib/python3.10/dist-packages (from astropy>=4->astroplan) (6.0.1)
# Requirement already satisfied: packaging>=19.0 in /usr/local/lib/python3.10/dist-packages (from astropy>=4->astroplan) (24.0)
# Building wheels for collected packages: astroplan
#   Building wheel for astroplan (pyproject.toml) ... done
#   Created wheel for astroplan: filename=astroplan-0.10-py3-none-any.whl size=83832 sha256=02de5e74e3102cfc20432d20d95ebea967972a5ed596cfb155a627d5db313f22
#   Stored in directory: /root/.cache/pip/wheels/f1/1d/bd/ce95e8776b8ebc0f8a432c8a18d9268ede4d9d5a5b24c22a6c
# Successfully built astroplan
# Installing collected packages: astroplan
# Successfully installed astroplan-0.10

# %%
from astropy.coordinates import get_body, SkyCoord
from astropy import units
from astropy.time import Time
from astroplan import Observer, FixedTarget, time_grid_from_range
import numpy as np
from datetime import datetime, timedelta, date

# %%
#SETUP
send_email=False

airmass_limit = 2.5
length=2 #in days
interval=60 #in minutes between samplings
start_time = datetime.now()
site_details = {'sitecode': 'Krakow', 'latitude': 50.05, 'longitude': 19.82, 'elevation': 300}
observer = Observer(longitude=site_details.get('longitude')*units.deg,
                    latitude=site_details.get('latitude')*units.deg,
                    elevation=site_details.get('elevation')*units.m)

# %%
#BHTOM token
from google.colab import userdata
auth_token=userdata.get('bhtomtoken')

# %%
def get_astroplan_sun_and_time(start_time, end_time, interval):
    """
    Uses astroplan's time_grid_from_range to generate
    an astropy Time object covering the time range.

    Uses astropy's get_sun to generate sun positions over
    that time range.

    If time range is small and interval is coarse, approximates
    the sun at a fixed position from the middle of the
    time range to speed up calculations.
    Since the sun moves ~4 minutes a day, this approximation
    happens when the number of days covered by the time range
    * 4 is less than the interval (in minutes) / 2.

    :param start_time: start of the window for which to calculate the airmass
    :type start_time: datetime

    :param end_time: end of the window for which to calculate the airmass
    :type end_time: datetime

    :param interval: time interval, in minutes, at which to calculate airmass within the given window
    :type interval: int

    :returns: ra/dec positions of the sun over the time range,
        time range between start_time and end_time at interval
    :rtype: astropy SkyCoord, astropy Time
    """

    start = Time(start_time)
    end = Time(end_time)

    time_range = time_grid_from_range(time_range=[start, end], time_resolution=interval*units.minute)

    number_of_days = end.mjd - start.mjd
    if number_of_days*4 < float(interval)/2:
        # Hack to speed up calculation by factor of ~3
        sun_coords = get_body("sun",time_range[int(len(time_range)/2)])
        sun = FixedTarget(name='sun', coord=SkyCoord(sun_coords.ra, sun_coords.dec, unit='deg'))
    else:
        sun = get_body("sun", time_range)

    return sun, time_range

# %%
#for a given target and observatory, returns true if the object is visible in the period provided
def check_visibility(name, ra, dec, observer, start_time, length=2, interval=60, airmass_limit=2.5):
  body = FixedTarget(name=name, coord=SkyCoord(ra, dec, unit='deg'))

  end_time = start_time + timedelta(days=length)

  visibility = {}
  sun, time_range = get_astroplan_sun_and_time(start_time, end_time, interval)
  sun_alt = observer.altaz(time_range, sun).alt
  obj_airmass = observer.altaz(time_range, body).secz

  bad_indices = np.argwhere(
      (obj_airmass >= airmass_limit) |
      (obj_airmass <= 1) |
      (sun_alt > -12*units.deg)  # between astronomical twilights, i.e. sun is up
  )

  obj_airmass = [None if i in bad_indices else float(airmass) for i, airmass in enumerate(obj_airmass)]

  # Check if all elements in obj_airmass are None
  if all(i is None for i in obj_airmass):
#      print("The list obj_airmass is full of None values.")
      return False
  else:
#      print("The list obj_airmass contains non-None values.")
      return True

# %%
name="Gaia24bfe"
ra,dec=311.33472,-17.57744

check_visibility(name, ra, dec, observer, start_time)
# Out:
# False

# %%
import requests
import pandas as pd
import json
from datetime import datetime, timedelta
import pytz

from IPython.display import display, HTML

# %%
 #asking for ALL targets, as for now, API does not allow for filtering on importance
request_body = {
         "decMin": -30

    }

# Define headers
headers = {
    'accept': 'application/json',
    'Authorization': f'Token {auth_token}',  ## you can hard-code your token here as well
    'Content-Type': 'application/json',
    'X-CSRFToken': 'uUz2fRnXhPuvD9YuuiDW9cD1LsajeaQnE4hwtEAfR00SgV9bD5HCe5i8n4m4KcOr'
}
api_url =  "https://bh-tom2.astrolabs.pl/targets/getTargetList/"

# Send the POST request
response = requests.post(api_url, json=request_body, headers=headers)

# Assuming response.text is your JSON data
data_json = json.loads(response.text)

data = json.loads(data_json)

#fields = data[0]['fields']

# Extracting field values into a list of dictionaries
data_list = [item['fields'] for item in data]

# Creating DataFrame from the list
df = pd.DataFrame(data_list)

#print(df)

# %%
df.columns
# Out:
# Index(['name', 'type', 'created', 'modified', 'ra', 'dec', 'epoch', 'parallax',
#        'pm_ra', 'pm_dec', 'galactic_lng', 'galactic_lat', 'distance',
#        'distance_err', 'scheme', 'epoch_of_elements', 'mean_anomaly',
#        'arg_of_perihelion', 'eccentricity', 'lng_asc_node', 'inclination',
#        'mean_daily_motion', 'semimajor_axis', 'epoch_of_perihelion',
#        'ephemeris_period', 'ephemeris_period_err', 'ephemeris_epoch',
#        'ephemeris_epoch_err', 'perihdist', 'classification', 'discovery_date',
#        'mjd_last', 'mag_last', 'importance', 'cadence', 'priority',
#        'sun_separation', 'creation_date', 'constellation', 'dont_update_me',
#        'phot_class', 'photometry_plot', 'photometry_plot_obs',
#        'photometry_icon_plot', 'spectroscopy_plot', 'data_plot', 'filter_last',
#        'cadence_priority', 'description'],
#       dtype='object')

# %%
#filtering on importance and sundistance
df0 = df[(df.importance > 1)].copy().reset_index(drop=True)

df1 = df[(df.importance > 4) & (df.sun_separation > 50) & (df.mag_last<18)].copy().reset_index(drop=True)

print(len(df0))
print(len(df1))
# Out:
# 154
# 44

# %%
# Convert 'created' column to datetime
df0['created'] = pd.to_datetime(df0['created'])
df1['created'] = pd.to_datetime(df1['created'])

# Get the date one week ago in UTC
one_week_ago = datetime.now(pytz.UTC) - timedelta(weeks=1)
current_date = datetime.now(pytz.UTC)
formatted_date = current_date.strftime("%d %B, %Y")

# Filter rows where 'created' is later than one week ago
df_lastweek = df0[df0['created'] > one_week_ago]
df_lastweek_sorted = df_lastweek.sort_values('mag_last')

df_old = df1[df1['created']<one_week_ago] #DF1 is also filtered by 18 mag
df_old_north = df_old[df_old['dec']>0]
df_old_south = df_old[df_old['dec']<=0]

df_old_N_sorted = df_old_north.sort_values('mag_last')
df_old_S_sorted = df_old_south.sort_values('mag_last')

df_lastweek_sorted
# Out:
#              name      type                          created  \
# 153  ZTF23aaqazhf  SIDEREAL 2024-05-30 18:09:48.023000+00:00
#
#                      modified          ra        dec   epoch parallax pm_ra  \
# 153  2024-05-31T08:43:07.409Z  285.385319  22.614975  2000.0     None  None
#
#     pm_dec  ...  dont_update_me       phot_class  \
# 153   None  ...            None  Red Giant 94.8%
#
#                               photometry_plot  \
# 153  /plots/photometry/ZTF23aaqazhf_plot.json
#
#                               photometry_plot_obs  \
# 153  /plots/photometry/obs_ZTF23aaqazhf_plot.json
#
#                              photometry_icon_plot spectroscopy_plot data_plot  \
# 153  /plots/photometryIcon/ZTF23aaqazhf_plot.json                        None
#
#     filter_last cadence_priority  \
# 153          ~G             10.4
#
#                                            description
# 153  potential microlensing event from FINK, KATS24...
#
# [1 rows x 49 columns]

# %%
# Selecting the required columns
df_lastweek_selected = df_lastweek_sorted[['name', 'ra', 'dec', 'mag_last', 'sun_separation', 'classification', 'description']]
df_old_N_selected = df_old_N_sorted[['name', 'ra', 'dec', 'mag_last', 'sun_separation', 'classification', 'description']]
df_old_S_selected = df_old_S_sorted[['name', 'ra', 'dec', 'mag_last', 'sun_separation', 'classification', 'description']]

# Define a function to format the strings
def make_hyperlink(name):
    return '<a href="https://bh-tom2.astrolabs.pl/targets/{0}/">{0}</a>'.format(name)

df_lastweek_selected = df_lastweek_selected.copy()
df_lastweek_selected.loc[:, 'name'] = df_lastweek_selected['name'].apply(make_hyperlink)

df_old_N_selected = df_old_N_selected.copy()
df_old_N_selected.loc[:, 'name'] = df_old_N_selected['name'].apply(make_hyperlink)

df_old_S_selected = df_old_S_selected.copy()
df_old_S_selected.loc[:, 'name'] = df_old_S_selected['name'].apply(make_hyperlink)

# Convert the DataFrame to HTML and escape=False to render HTML tags
html_table = df_lastweek_selected.to_html(index=False, escape=False)
# Remove border by replacing <table> with <table border="0">
html_table = html_table.replace('<table', '<table border="0"')

old_N_table = df_old_N_selected.to_html(index=False, escape=False)
old_N_table = old_N_table.replace('<table', '<table border="0"')
old_S_table = df_old_S_selected.to_html(index=False, escape=False)
old_S_table = old_S_table.replace('<table', '<table border="0"')

link_N = "https://bh-tom2.astrolabs.pl/targets/?type=&name=&classification=&description=&cone_search=&targetlist__name=&target_cone_search=&ra_min=&ra_max=&dec_min=0&dec_max=&gall_min=&gall_max=&galb_min=&galb_max=&importance_min=4&importance_max=&priority_min=&priority_max=&sun_min=70&sun_max=&mag_min=&mag_max=18&order=mag_last"
link_S = "https://bh-tom2.astrolabs.pl/targets/?type=&name=&classification=&description=&cone_search=&targetlist__name=&target_cone_search=&ra_min=&ra_max=&dec_min=&dec_max=0&gall_min=&gall_max=&galb_min=&galb_max=&importance_min=4&importance_max=&priority_min=&priority_max=&sun_min=70&sun_max=&mag_min=&mag_max=18&order=mag_last"

# %%
#asking for dataproducts from last week
from datetime import datetime
from dateutil.relativedelta import relativedelta

# Get the current date and time
now = datetime.now()

# Calculate the date a week ago
week_ago = now - relativedelta(weeks=1)

# Format the date as a string in the required format
week_ago_str = week_ago.strftime("%Y-%m-%dT%H:%M:%S.%f%z")
beginning_2024 = "2024-01-01T00:00:00.00+00:00"
date = "2024-05-01T00:00:00.00+00:00"
#

request_body = {
    "created_start": week_ago_str,
}

# request_body = {
#     "created_start":"2023-01-01T00:06:23.653199+01:00"
#     }

# Define headers
headers = {
    'accept': 'application/json',
    'Authorization': f'Token {auth_token}',  ## you can hard-code your token here as well
    'Content-Type': 'application/json',
    'X-CSRFToken': 'uUz2fRnXhPuvD9YuuiDW9cD1LsajeaQnE4hwtEAfR00SgV9bD5HCe5i8n4m4KcOr'
}
api_url =  "https://bh-tom2.astrolabs.pl/common/api/data/"

# Send the POST request
response = requests.post(api_url, json=request_body, headers=headers)

# Assuming response.text is your JSON data
data_json = json.loads(response.text)

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(data_json)

# %%
df = pd.DataFrame(data_json)
df.drop(df[df['dryRun'] == True].index, inplace=True)

df.columns
# Out:
# Index(['id', 'user_name', 'target_name', 'target', 'user', 'camera',
#        'observatory_name', 'observatory', 'product_id', 'data', 'status',
#        'photometry_data', 'fits_data', 'extra_data', 'created', 'modified',
#        'data_product_type', 'featured', 'thumbnail', 'dryRun', 'comment',
#        'observation_record', 'group'],
#       dtype='object')

# %%
# #grabbing observatory list:
# # Define headers
# request_body = {
#          "decMin": -1000

#     }

# headers = {
#     'accept': 'application/json',
#     'Authorization': f'Token {auth_token}',  ## you can hard-code your token here as well
#     'Content-Type': 'application/json',
#     'X-CSRFToken': 'uUz2fRnXhPuvD9YuuiDW9cD1LsajeaQnE4hwtEAfR00SgV9bD5HCe5i8n4m4KcOr'
# }
# api_url =  "https://bh-tom2.astrolabs.pl/observatory/getObservatoryList/"

# # Send the POST request
# response = requests.post(api_url, json=request_body, headers=headers)
# #response

# # # Assuming response.text is your JSON data
# data_json = json.loads(response.text)

# data = json.loads(data_json)

# #fields = data[0]['fields']

# # Extracting field values into a list of dictionaries
# data_list = [item['fields'] for item in data]

# # Creating DataFrame from the list
# df_obs = pd.DataFrame(data_list)

# %%
# df_obs.columns

# %%
total_fits = len(df)
total_fits
# Out:
# 5301

# %%
# #adding prefix column to my main df with observations:

# #note that df already contains name and prefix, but are all Nans - why?
# # Merge df with df_obs on 'observatory' and 'name'
# merged_df = pd.merge(df, df_obs[['name', 'prefix']], left_on='observatory', right_on='name', how='left')

# merged_df.drop('name', axis=1, inplace=True)
# merged_df = merged_df.rename(columns={'prefix': 'observatory_prefix'})

# # If you want to replace the original df with the merged one
# df = merged_df

# %%
# Create a new column 'observatory_user' that combines 'observatory' and 'user'
df['observatory_user'] = df['user_name'] + " ("+df['camera'] + ")"

# Count the occurrences of each unique 'observatory_user', and get the top 5
top_5 = df['user_name'].value_counts().head(5)
top_5_df = top_5.reset_index()
top_5_df.columns = ['name', 'count']
top_5_html = top_5_df.to_html(index=False)

top_5_html
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>name</th>\n      <th>count</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td>Rachel Street</td>\n      <td>1825</td>\n    </tr>\n    <tr>\n      <td>Franz-Josef Hambsch</td>\n      <td>1370</td>\n    </tr>\n    <tr>\n      <td>Supachai Awiphan</td>\n      <td>945</td>\n    </tr>\n    <tr>\n      <td>Katarzyna Kruszynska</td>\n      <td>271</td>\n    </tr>\n    <tr>\n      <td>Sjoerd Dufoer</td>\n      <td>239</td>\n    </tr>\n  </tbody>\n</table>'

# %%
df['created'] = pd.to_datetime(df['created'])
one_week_ago = datetime.now(pytz.UTC) - timedelta(weeks=1)
df_last_week = df[df['created'] > one_week_ago]
#TEMP: ALL
#df_last_week = df
last_week_counts = df_last_week['observatory_user'].value_counts()

# %%
# Group by 'target_name' and apply join on unique 'user_name'
df_grouped = df_last_week.groupby('target_name')['user_name'].apply(lambda x: ', '.join(set(x))).reset_index()

# Rename the columns as per your requirement
df_grouped.columns = ['target_name', 'user_names']

# Convert DataFrame to HTML, remove index, justify all columns to the right
html_grouped = df_grouped.to_html(index=False)

# Add style to justify text to the right for all columns
html_grouped = html_grouped.replace('<table', '<table border="0" style="text-align: right;"')

# Display HTML string in Google Colab
display(HTML(html_grouped))
# Out:
# <table border="0" style="text-align: right;" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>target_name</th>
#       <th>user_names</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>8C0716_714</td>
#       <td>Justas Zdanavicius</td>
#     </tr>
#     <tr>
#       <td>ASASSN-14cc</td>
#       <td>Magdalena Szkudlarek</td>
#     </tr>
#     <tr>
#       <td>Gaia14aaf</td>
#       <td>Chris OHare</td>
#     </tr>
#     <tr>
#       <td>Gaia19bpg</td>
#       <td>Adam Popowicz</td>
#     </tr>
#     <tr>
#       <td>Gaia21asp</td>
#       <td>Adam Popowicz</td>
#     </tr>
#     <tr>
#       <td>Gaia21ccu</td>
#       <td>Franz-Josef Hambsch</td>
#     </tr>
#     <tr>
#       <td>Gaia22alz</td>
#       <td>Staszek Zola</td>
#     </tr>
#     <tr>
#       <td>Gaia22bpl</td>
#       <td>Supachai Awiphan</td>
#     </tr>
#     <tr>
#       <td>Gaia23ats</td>
#       <td>Supachai Awiphan</td>
#     </tr>
#     <tr>
#       <td>Gaia23bay</td>
#       <td>Supachai Awiphan</td>
#     </tr>
#     <tr>
#       <td>Gaia23bor</td>
#       <td>Supachai Awiphan</td>
#     </tr>
#     <tr>
#       <td>Gaia23ckh</td>
#       <td>Supachai Awiphan</td>
#     </tr>
#     <tr>
#       <td>Gaia23cpd</td>
#       <td>Josep Manel Carrasco, Sjoerd Dufoer</td>
#     </tr>
#     <tr>
#       <td>Gaia23cri</td>
#       <td>Uliana Pylypenko</td>
#     </tr>
#     <tr>
#       <td>Gaia23cxu</td>
#       <td>Uliana Pylypenko</td>
#     </tr>
#     <tr>
#       <td>Gaia23dgt</td>
#       <td>Supachai Awiphan</td>
#     </tr>
#     <tr>
#       <td>Gaia23dpd</td>
#       <td>Uliana Pylypenko</td>
#     </tr>
#     <tr>
#       <td>Gaia23dpi</td>
#       <td>Uliana Pylypenko</td>
#     </tr>
#     <tr>
#       <td>Gaia23dpn</td>
#       <td>Franz-Josef Hambsch, Uliana Pylypenko</td>
#     </tr>
#     <tr>
#       <td>Gaia24acn</td>
#       <td>Rachel Street, Przemyslaw J. Mikolajczyk, Fraser Lewis, Uliana Pylypenko, Josep Manel Carrasco, Katarzyna Kruszynska</td>
#     </tr>
#     <tr>
#       <td>Gaia24amk</td>
#       <td>Uliana Pylypenko</td>
#     </tr>
#     <tr>
#       <td>Gaia24amo</td>
#       <td>Uliana Pylypenko</td>
#     </tr>
#     <tr>
#       <td>Gaia24asr</td>
#       <td>Supachai Awiphan, Uliana Pylypenko</td>
#     </tr>
#     <tr>
#       <td>Gaia24ata</td>
#       <td>Uliana Pylypenko</td>
#     </tr>
#     <tr>
#       <td>Gaia24aup</td>
#       <td>Josep Manel Carrasco</td>
#     </tr>
#     <tr>
#       <td>Gaia24avs</td>
#       <td>Rachel Walls, Stewart Cruickshank</td>
#     </tr>
#     <tr>
#       <td>Gaia24ayd</td>
#       <td>Justas Zdanavicius, Franky Dubois, Sjoerd Dufoer</td>
#     </tr>
#     <tr>
#       <td>Gaia24azc</td>
#       <td>Justas Zdanavicius, Franky Dubois, Uliana Pylypenko</td>
#     </tr>
#     <tr>
#       <td>Gaia24azi</td>
#       <td>Supachai Awiphan, Justas Zdanavicius, Cihan Tuğrul Tezcan, Sjoerd Dufoer, Steve Fossey, Franz-Josef Hambsch, Rachel Street, Fraser Lewis, Stephen M. Brincat, Uliana Pylypenko, Franky Dubois, Katarzyna Kruszynska</td>
#     </tr>
#     <tr>
#       <td>Gaia24bau</td>
#       <td>Supachai Awiphan</td>
#     </tr>
#     <tr>
#       <td>Gaia24bct</td>
#       <td>Staszek Zola</td>
#     </tr>
#     <tr>
#       <td>Gaia24beh</td>
#       <td>Aaron Massiah</td>
#     </tr>
#     <tr>
#       <td>Gaia24bfe</td>
#       <td>Franky Dubois, Sjoerd Dufoer</td>
#     </tr>
#     <tr>
#       <td>Gaia24bfr</td>
#       <td>Franz-Josef Hambsch</td>
#     </tr>
#     <tr>
#       <td>Gaia24bhf</td>
#       <td>Garry Haslett, Anthony Friend, Sean Norris</td>
#     </tr>
#     <tr>
#       <td>Gaia24bhu</td>
#       <td>Naomi McCormick</td>
#     </tr>
#     <tr>
#       <td>Gaia24bic</td>
#       <td>Joanna Link</td>
#     </tr>
#     <tr>
#       <td>Gaia24biz</td>
#       <td>Matthew Oxborrow</td>
#     </tr>
#     <tr>
#       <td>KMT-2024-BLG-0089</td>
#       <td>Przemyslaw J. Mikolajczyk</td>
#     </tr>
#     <tr>
#       <td>NGC5683-Seyfert</td>
#       <td>Uliana Pylypenko</td>
#     </tr>
#     <tr>
#       <td>SN 2024igg</td>
#       <td>Uliana Pylypenko</td>
#     </tr>
#     <tr>
#       <td>TCrB</td>
#       <td>Justas Zdanavicius, Stephen M. Brincat, Josep Manel Carrasco, Uliana Pylypenko</td>
#     </tr>
#     <tr>
#       <td>TabbysStar</td>
#       <td>Stephen M. Brincat</td>
#     </tr>
#     <tr>
#       <td>ZTF23aaqazhf</td>
#       <td>Rachel Street</td>
#     </tr>
#     <tr>
#       <td>ZTF24aaiafkl</td>
#       <td>Rachel Street</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Group by 'observatory' and apply join on unique 'target_name'
df_grouped_obs = df_last_week.groupby('camera')['target_name'].apply(lambda x: ', '.join(set(x))).reset_index()

# Apply the make_hyperlink function to each target_name
#df_grouped_obs['target_name'] = df_grouped_obs['target_name'].str.split(', ').apply(lambda names: ', '.join(make_hyperlink(name) for name in names))

# Rename the columns as per your requirement
df_grouped_obs.columns = ['camera', 'target_names']

# Convert DataFrame to HTML, remove index, justify all columns to the right
html_grouped_obs = df_grouped_obs.to_html(index=False)

# Add style to justify text to the right for all columns
html_grouped_obs = html_grouped_obs.replace('<table', '<table border="0" style="text-align: right;"')

# Display HTML string in Google Colab
display(HTML(html_grouped_obs))
#df_grouped_obs
# Out:
# <table border="0" style="text-align: right;" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>camera</th>
#       <th>target_names</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Adonis_G2-1600</td>
#       <td>Gaia24bfe, Gaia24ayd, Gaia24azc, Gaia24azi</td>
#     </tr>
#     <tr>
#       <td>CAHA1.23_ASI461MM</td>
#       <td>Gaia24azc, TCrB, Gaia24azi, SN 2024igg, NGC5683-Seyfert</td>
#     </tr>
#     <tr>
#       <td>EEye_QHY268M</td>
#       <td>Gaia24azi, Gaia24ayd, Gaia24bfe, Gaia23cpd</td>
#     </tr>
#     <tr>
#       <td>ElSauce_QHY600MPro</td>
#       <td>Gaia24azi</td>
#     </tr>
#     <tr>
#       <td>Flarestar-MPC171_G2-1600</td>
#       <td>TCrB, TabbysStar, Gaia24azi</td>
#     </tr>
#     <tr>
#       <td>LCOGT-CTIO-1m_4K</td>
#       <td>Gaia24ata, ZTF23aaqazhf, Gaia23dpn, Gaia24azi, Gaia24amo, Gaia23dpi, Gaia24asr</td>
#     </tr>
#     <tr>
#       <td>LCOGT-HO-2m_Spectral</td>
#       <td>Gaia24acn, Gaia24bhf, Gaia24azi</td>
#     </tr>
#     <tr>
#       <td>LCOGT-MCD-1m_4K</td>
#       <td>ZTF23aaqazhf, Gaia24acn, Gaia24azi</td>
#     </tr>
#     <tr>
#       <td>LCOGT-SAAO-1m_4K</td>
#       <td>Gaia24amk, Gaia23dpi, ZTF24aaiafkl, Gaia24asr, Gaia23dpd</td>
#     </tr>
#     <tr>
#       <td>LCOGT-SS-1m_4K</td>
#       <td>Gaia23dpn, Gaia24azi, Gaia24amk, Gaia23dpi, Gaia23cxu</td>
#     </tr>
#     <tr>
#       <td>LCOGT-SS-2m_Spectral</td>
#       <td>Gaia24azi</td>
#     </tr>
#     <tr>
#       <td>LCOGT-Teide-1m_4K</td>
#       <td>Gaia23cri, ZTF23aaqazhf, Gaia24acn, Gaia24azi</td>
#     </tr>
#     <tr>
#       <td>MOLETAI-35cm_CCD4710</td>
#       <td>Gaia24azc, 8C0716_714, Gaia24azi, Gaia24ayd, TCrB</td>
#     </tr>
#     <tr>
#       <td>PIRATE_FLI</td>
#       <td>Gaia24bhu, Gaia14aaf, Gaia24bhf, Gaia24bic, Gaia24biz, Gaia24beh, Gaia24avs</td>
#     </tr>
#     <tr>
#       <td>PROMPT-MO-1_Apogee</td>
#       <td>Gaia24bct, Gaia22alz</td>
#     </tr>
#     <tr>
#       <td>REM_REMIR</td>
#       <td>KMT-2024-BLG-0089</td>
#     </tr>
#     <tr>
#       <td>ROAD_QHY600M</td>
#       <td>Gaia24bfr, Gaia21ccu, Gaia23dpn, Gaia24azi</td>
#     </tr>
#     <tr>
#       <td>SUTO-Otivar_ASI1600MM</td>
#       <td>Gaia21asp, Gaia19bpg</td>
#     </tr>
#     <tr>
#       <td>TJO_MEIA3</td>
#       <td>TCrB, Gaia24acn, Gaia24aup, Gaia23cpd</td>
#     </tr>
#     <tr>
#       <td>TRT-CTO-0.7_Andor-934</td>
#       <td>Gaia24bau, Gaia24asr, Gaia23ckh, Gaia24azi</td>
#     </tr>
#     <tr>
#       <td>TRT-SBO-0.7_Andor-934</td>
#       <td>Gaia24bau, Gaia23ckh, Gaia22bpl, Gaia23bor, Gaia24asr, Gaia23ats</td>
#     </tr>
#     <tr>
#       <td>TRT-SRO-0.7_Andor-934</td>
#       <td>Gaia23bay, Gaia23dgt, Gaia24azi</td>
#     </tr>
#     <tr>
#       <td>UCLO-C14EAST_PL9000</td>
#       <td>Gaia24azi</td>
#     </tr>
#     <tr>
#       <td>UZPW50_Chile_QHY268PRO</td>
#       <td>ASASSN-14cc</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Convert Series to DataFrame and rename columns
df = last_week_counts.to_frame().reset_index()
df.columns = ['observatory-user', 'count']

# Convert DataFrame to HTML, remove index, justify all columns to the right
html_last_week_count = df.to_html(index=False)

# Add style to justify text to the right for all columns
html_last_week_count = html_last_week_count.replace('<table', '<table border="0" style="text-align: right;"')

# Display HTML string in Google Colab
display(HTML(html_last_week_count))
# Out:
# <table border="0" style="text-align: right;" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>observatory-user</th>
#       <th>count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Franz-Josef Hambsch (ROAD_QHY600M)</td>
#       <td>1370</td>
#     </tr>
#     <tr>
#       <td>Rachel Street (LCOGT-CTIO-1m_4K)</td>
#       <td>762</td>
#     </tr>
#     <tr>
#       <td>Supachai Awiphan (TRT-SRO-0.7_Andor-934)</td>
#       <td>472</td>
#     </tr>
#     <tr>
#       <td>Rachel Street (LCOGT-SS-1m_4K)</td>
#       <td>372</td>
#     </tr>
#     <tr>
#       <td>Rachel Street (LCOGT-MCD-1m_4K)</td>
#       <td>355</td>
#     </tr>
#     <tr>
#       <td>Rachel Street (LCOGT-Teide-1m_4K)</td>
#       <td>332</td>
#     </tr>
#     <tr>
#       <td>Supachai Awiphan (TRT-SBO-0.7_Andor-934)</td>
#       <td>330</td>
#     </tr>
#     <tr>
#       <td>Sjoerd Dufoer (EEye_QHY268M)</td>
#       <td>239</td>
#     </tr>
#     <tr>
#       <td>Katarzyna Kruszynska (LCOGT-SS-2m_Spectral)</td>
#       <td>144</td>
#     </tr>
#     <tr>
#       <td>Supachai Awiphan (TRT-CTO-0.7_Andor-934)</td>
#       <td>143</td>
#     </tr>
#     <tr>
#       <td>Katarzyna Kruszynska (LCOGT-HO-2m_Spectral)</td>
#       <td>124</td>
#     </tr>
#     <tr>
#       <td>Stephen M. Brincat (Flarestar-MPC171_G2-1600)</td>
#       <td>119</td>
#     </tr>
#     <tr>
#       <td>Adam Popowicz (SUTO-Otivar_ASI1600MM)</td>
#       <td>95</td>
#     </tr>
#     <tr>
#       <td>Uliana Pylypenko (CAHA1.23_ASI461MM)</td>
#       <td>76</td>
#     </tr>
#     <tr>
#       <td>Justas Zdanavicius (MOLETAI-35cm_CCD4710)</td>
#       <td>48</td>
#     </tr>
#     <tr>
#       <td>Josep Manel Carrasco (TJO_MEIA3)</td>
#       <td>46</td>
#     </tr>
#     <tr>
#       <td>Uliana Pylypenko (LCOGT-CTIO-1m_4K)</td>
#       <td>39</td>
#     </tr>
#     <tr>
#       <td>Steve Fossey (ElSauce_QHY600MPro)</td>
#       <td>32</td>
#     </tr>
#     <tr>
#       <td>Uliana Pylypenko (LCOGT-Teide-1m_4K)</td>
#       <td>26</td>
#     </tr>
#     <tr>
#       <td>Steve Fossey (UCLO-C14EAST_PL9000)</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <td>Staszek Zola (PROMPT-MO-1_Apogee)</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <td>Franky Dubois (Adonis_G2-1600)</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <td>Naomi McCormick (PIRATE_FLI)</td>
#       <td>18</td>
#     </tr>
#     <tr>
#       <td>Uliana Pylypenko (LCOGT-SS-1m_4K)</td>
#       <td>16</td>
#     </tr>
#     <tr>
#       <td>Uliana Pylypenko (LCOGT-SAAO-1m_4K)</td>
#       <td>11</td>
#     </tr>
#     <tr>
#       <td>Aaron Massiah (PIRATE_FLI)</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <td>Joanna Link (PIRATE_FLI)</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>Magdalena Szkudlarek (UZPW50_Chile_QHY268PRO)</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>Sean Norris (PIRATE_FLI)</td>
#       <td>6</td>
#     </tr>
#     <tr>
#       <td>Rachel Street (LCOGT-SAAO-1m_4K)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>Fraser Lewis (LCOGT-SS-1m_4K)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>Garry Haslett (LCOGT-HO-2m_Spectral)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>Stewart Cruickshank (PIRATE_FLI)</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <td>Matthew Oxborrow (PIRATE_FLI)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>Fraser Lewis (LCOGT-HO-2m_Spectral)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>Rachel Walls (PIRATE_FLI)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>Anthony Friend (PIRATE_FLI)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>Katarzyna Kruszynska (LCOGT-Teide-1m_4K)</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <td>Fraser Lewis (LCOGT-MCD-1m_4K)</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Fraser Lewis (LCOGT-CTIO-1m_4K)</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Chris OHare (PIRATE_FLI)</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Uliana Pylypenko (LCOGT-MCD-1m_4K)</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Przemyslaw J. Mikolajczyk (REM_REMIR)</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Przemyslaw J. Mikolajczyk (LCOGT-Teide-1m_4K)</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Fraser Lewis (LCOGT-Teide-1m_4K)</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>

# %%
# prompt: from df_last_week list count of unique entries in target column

unique_targets = df_last_week['target_name'].value_counts()

unique_targets
# Out:
# target_name
# Gaia24azi            3049
# Gaia24acn             426
# Gaia23bay             324
# Gaia21ccu             179
# Gaia24bfr             139
# Gaia23dpn             130
# TCrB                  110
# Gaia23ats             101
# Gaia23bor              93
# Gaia24asr              90
# Gaia23dgt              85
# Gaia23ckh              75
# Gaia21asp              63
# ZTF23aaqazhf           51
# Gaia24bau              40
# Gaia22bpl              39
# Gaia23cpd              38
# Gaia24bfe              35
# Gaia24ayd              34
# Gaia19bpg              32
# Gaia24bhu              18
# TabbysStar             15
# Gaia24bhf              13
# Gaia24azc              12
# Gaia24bct              12
# Gaia23dpi               9
# Gaia24amk               8
# Gaia22alz               8
# Gaia24beh               8
# Gaia24aup               8
# Gaia24avs               7
# Gaia24amo               7
# ASASSN-14cc             6
# Gaia24bic               6
# 8C0716_714              6
# ZTF24aaiafkl            4
# SN 2024igg              4
# Gaia24biz               3
# NGC5683-Seyfert         3
# Gaia24ata               3
# Gaia23cri               2
# Gaia23cxu               2
# Gaia14aaf               2
# Gaia23dpd               1
# KMT-2024-BLG-0089       1
# Name: count, dtype: int64

# %%
df_last_week
# Out:
#           id         user_name      target_name  target                 user  \
# 0     169502      Steve Fossey        Gaia24azi    3012  steve@fossey.org.uk
# 1     169503      Steve Fossey        Gaia24azi    3012  steve@fossey.org.uk
# 2     169504      Steve Fossey        Gaia24azi    3012  steve@fossey.org.uk
# 3     169505      Steve Fossey        Gaia24azi    3012  steve@fossey.org.uk
# 4     169506      Steve Fossey        Gaia24azi    3012  steve@fossey.org.uk
# ...      ...               ...              ...     ...                  ...
# 5468  175302  Uliana Pylypenko             TCrB    2693               uliana
# 5469  175303  Uliana Pylypenko             TCrB    2693               uliana
# 5470  175304  Uliana Pylypenko  NGC5683-Seyfert    2865               uliana
# 5471  175305  Uliana Pylypenko  NGC5683-Seyfert    2865               uliana
# 5472  175306  Uliana Pylypenko  NGC5683-Seyfert    2865               uliana
#
#                    camera       observatory_name  observatory product_id  \
# 0     UCLO-C14EAST_PL9000    UCLO C14 EAST 36-cm         47.0       None
# 1     UCLO-C14EAST_PL9000    UCLO C14 EAST 36-cm         47.0       None
# 2     UCLO-C14EAST_PL9000    UCLO C14 EAST 36-cm         47.0       None
# 3     UCLO-C14EAST_PL9000    UCLO C14 EAST 36-cm         47.0       None
# 4     UCLO-C14EAST_PL9000    UCLO C14 EAST 36-cm         47.0       None
# ...                   ...                    ...          ...        ...
# 5468    CAHA1.23_ASI461MM  CAHA 1.23-m Telescope        160.0       None
# 5469    CAHA1.23_ASI461MM  CAHA 1.23-m Telescope        160.0       None
# 5470    CAHA1.23_ASI461MM  CAHA 1.23-m Telescope        160.0       None
# 5471    CAHA1.23_ASI461MM  CAHA 1.23-m Telescope        160.0       None
# 5472    CAHA1.23_ASI461MM  CAHA 1.23-m Telescope        160.0       None
#
#                                                    data  ...  \
# 0     /data/fits/Gaia24azi/45_2024_05_27T23_42_59_Ga...  ...
# 1     /data/fits/Gaia24azi/45_2024_05_27T23_46_42_Ga...  ...
# 2     /data/fits/Gaia24azi/45_2024_05_27T23_50_23_Ga...  ...
# 3     /data/fits/Gaia24azi/45_2024_05_28T00_07_35_Ga...  ...
# 4     /data/fits/Gaia24azi/45_2024_05_28T00_11_22_Ga...  ...
# ...                                                 ...  ...
# 5468  /data/fits/TCrB/114_TCrB_22_05_2024T20_06_15_0...  ...
# 5469  /data/fits/TCrB/114_TCrB_22_05_2024T19_59_22_0...  ...
# 5470  /data/fits/NGC5683_Seyfert/114_NGC5683_Seyfert...  ...
# 5471  /data/fits/NGC5683_Seyfert/114_NGC5683_Seyfert...  ...
# 5472  /data/fits/NGC5683_Seyfert/114_NGC5683_Seyfert...  ...
#
#                               created                          modified  \
# 0    2024-05-28 08:30:54.635518+02:00  2024-05-28T08:54:43.766769+02:00
# 1    2024-05-28 08:30:54.865673+02:00  2024-05-28T08:54:45.055965+02:00
# 2    2024-05-28 08:30:55.031039+02:00  2024-05-28T09:14:44.915648+02:00
# 3    2024-05-28 08:32:53.298382+02:00  2024-05-28T08:50:43.327850+02:00
# 4    2024-05-28 08:32:53.482952+02:00  2024-05-28T09:14:25.705550+02:00
# ...                               ...                               ...
# 5468 2024-06-03 20:39:17.115779+02:00  2024-06-03T20:40:01.913731+02:00
# 5469 2024-06-03 20:39:34.654388+02:00  2024-06-03T20:40:18.493293+02:00
# 5470 2024-06-03 21:36:52.312266+02:00  2024-06-03T21:37:38.829934+02:00
# 5471 2024-06-03 21:39:56.059625+02:00  2024-06-03T21:40:43.582053+02:00
# 5472 2024-06-03 21:39:57.390356+02:00  2024-06-03T21:40:44.309983+02:00
#
#      data_product_type featured thumbnail dryRun comment  observation_record  \
# 0            fits_file    False      None  False    None                None
# 1            fits_file    False      None  False    None                None
# 2            fits_file    False      None  False    None                None
# 3            fits_file    False      None  False    None                None
# 4            fits_file    False      None  False    None                None
# ...                ...      ...       ...    ...     ...                 ...
# 5468         fits_file    False      None  False    None                None
# 5469         fits_file    False      None  False    None                None
# 5470         fits_file    False      None  False    None                None
# 5471         fits_file    False      None  False    None                None
# 5472         fits_file    False      None  False    None                None
#
#      group                      observatory_user
# 0       []    Steve Fossey (UCLO-C14EAST_PL9000)
# 1       []    Steve Fossey (UCLO-C14EAST_PL9000)
# 2       []    Steve Fossey (UCLO-C14EAST_PL9000)
# 3       []    Steve Fossey (UCLO-C14EAST_PL9000)
# 4       []    Steve Fossey (UCLO-C14EAST_PL9000)
# ...    ...                                   ...
# 5468    []  Uliana Pylypenko (CAHA1.23_ASI461MM)
# 5469    []  Uliana Pylypenko (CAHA1.23_ASI461MM)
# 5470    []  Uliana Pylypenko (CAHA1.23_ASI461MM)
# 5471    []  Uliana Pylypenko (CAHA1.23_ASI461MM)
# 5472    []  Uliana Pylypenko (CAHA1.23_ASI461MM)
#
# [5301 rows x 24 columns]

# %%
# Get counts of each status
status_counts = df_last_week['status'].value_counts()

# Print counts
print(status_counts)

# Count for success statuses
success_count = status_counts.get('S', 0)
print(f'Success count: {success_count}')

# Count for error statuses
error_count = status_counts.get('E', 0)
print(f'Error count: {error_count}')

# Count for other statuses
other_count = status_counts.sum() - success_count - error_count
print(f'Other statuses count: {other_count}')
# Out:
# status
# S    4797
# E     479
# P      21
# R       4
# Name: count, dtype: int64
# Success count: 4797
# Error count: 479
# Other statuses count: 25

# %% [markdown]
# #formating the email

# %%
# Creating the email message
email_message = f"""
Hello,
<p>
Greetings from the BHTOM Automated Newsletter!
</p>
<p>

</p>
<p>
As of {current_date}, these are the new targets added in the last week with importance greater than 1, sorted by magnitude:
</p>
<p>
{html_table}
</p>
<p>
In addition, here are some older targets that are currently visible and requested for observations. These targets have an importance greater than 4, a sun separation greater than 70, and a magnitude less than 18. They are also sorted by magnitude.
</p>
<hr>
<p>
<b><a href="{link_N}">North (dec>0):</a></b>
<br>
{old_N_table}
</p>
<hr>
<p>
<b><a href="{link_S}">South (dec<0):</a></b>
<br>
{old_S_table}
</p>
<hr>
<p>
<b>Last week's total of images processed: {total_fits} ({success_count} with success).</b>
<hr>
<p>
<b>Last week's targets observed:</b>
<br>
{html_grouped_obs}
</p>
<p>
<b>Last week's fits uploads score</b> (sorted by count)
<br>
{html_last_week_count}
</p>
<p>
<p>
<hr>
<b>Top 5 data uploaders!</b>
{top_5_html}
<p>
<p>
<hr>
Clear skies!
<br>
Your BHTOM Team
<br>
<a href="http://bhtom.space">bhtom.space</a>
</p>
"""#.format(current_date, html_table, old_N_table, old_S_table, link_N, link_S, html_grouped_obs, html_last_week_count)

# %%
email_message
# Out:
# '\nHello,\n<p>\nGreetings from the BHTOM Automated Newsletter!\n</p>\n<p>\n\n</p>\n<p>\nAs of 2024-06-04 05:26:33.080591+00:00, these are the new targets added in the last week with importance greater than 1, sorted by magnitude:\n</p>\n<p>\n<table border="0" border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>name</th>\n      <th>ra</th>\n      <th>dec</th>\n      <th>mag_last</th>\n      <th>sun_separation</th>\n      <th>classification</th>\n      <th>description</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/ZTF23aaqazhf/">ZTF23aaqazhf</a></td>\n      <td>285.385319</td>\n      <td>22.614975</td>\n      <td>15.9</td>\n      <td>125.0</td>\n      <td>Unknown</td>\n      <td>potential microlensing event from FINK, KATS24K002</td>\n    </tr>\n  </tbody>\n</table>\n</p>\n<p>\nIn addition, here are some older targets that are currently visible and requested for observations. These targets have an importance greater than 4, a sun separation greater than 70, and a magnitude less than 18. They are also sorted by magnitude.\n</p>\n<hr>\n<p>\n<b><a href="https://bh-tom2.astrolabs.pl/targets/?type=&name=&classification=&description=&cone_search=&targetlist__name=&target_cone_search=&ra_min=&ra_max=&dec_min=0&dec_max=&gall_min=&gall_max=&galb_min=&galb_max=&importance_min=4&importance_max=&priority_min=&priority_max=&sun_min=70&sun_max=&mag_min=&mag_max=18&order=mag_last">North (dec>0):</a></b>\n<br>\n<table border="0" border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th>name</th>\n      <th>ra</th>\n      <th>dec</th>\n      <th>mag_last</th>\n      <th>sun_separation</th>\n      <th>classification</th>\n      <th>description</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/TCrB/">TCrB</a></td>\n      <td>239.875676</td>\n      <td>25.920170</td>\n      <td>10.9</td>\n      <td>130.0</td>\n      <td>Nova</td>\n      <td>recurent nova predicted to explode 2024/2025</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/4U2206+54/">4U2206+54</a></td>\n      <td>331.984320</td>\n      <td>54.518447</td>\n      <td>11.3</td>\n      <td>78.0</td>\n      <td>XRB</td>\n      <td>Be X-ray binary</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia24ayd/">Gaia24ayd</a></td>\n      <td>300.825090</td>\n      <td>30.651260</td>\n      <td>12.9</td>\n      <td>109.0</td>\n      <td>Unknown</td>\n      <td>bright candidate for microlensing event</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/SAXJ2103.5+4545/">SAXJ2103.5+4545</a></td>\n      <td>315.898792</td>\n      <td>45.751547</td>\n      <td>13.7</td>\n      <td>91.0</td>\n      <td>XRB</td>\n      <td>Be X-ray binary</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/IGRJ21343+4738/">IGRJ21343+4738</a></td>\n      <td>323.584883</td>\n      <td>47.633391</td>\n      <td>14.0</td>\n      <td>85.0</td>\n      <td>XRB</td>\n      <td>Be X-ray binary</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/KS1947+300/">KS1947+300</a></td>\n      <td>297.397850</td>\n      <td>30.208827</td>\n      <td>14.1</td>\n      <td>112.0</td>\n      <td>XRB</td>\n      <td>Be X-ray binary</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/GROJ2058+42/">GROJ2058+42</a></td>\n      <td>314.698071</td>\n      <td>41.776995</td>\n      <td>14.3</td>\n      <td>94.0</td>\n      <td>XRB</td>\n      <td>Be X-ray binary</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.astrolabs.pl/targets/SN 2024igg/">SN 2024igg</a></td>\n      <td>227.378793</td>\n      <td>54.505622</td>\n      <td>14.6</td>\n      <td>100.0</td>\n      <td>SN</td>\n      <td>Astro-COLIBRI target</td>\n    </tr>\n    <tr>\n      <td><a href="https://bh-tom2.as ...

# %%
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from getpass import getpass

if send_email:
  # Set up the SMTP server
  # Set up the SMTP server
  s = smtplib.SMTP(host='smtp.gmail.com', port=587)
  s.starttls()

  # Login to your Gmail account
  password = 'ggzr clob tbcm ehtc'
  s.login('wyrzykow@gmail.com', password)

  # Create a message
  msg = MIMEMultipart()  # create a message

  # Setup the parameters of the message
  msg['From']="wyrzykow@gmail.com"
  msg['To']="bhtomtargets@googlegroups.com"
  msg['Subject']=f"BHTOM Targets for {formatted_date}"

  msg.attach(MIMEText(email_message, 'html'))

  # Send the message via the server set up earlier.
  s.send_message(msg)

  # Terminate the SMTP session and close the connection
  s.quit()

# %%
### Separate code for BHTOM webpage:
# recently observed events - target names
# one-year statistics: winners per users

# %%
display(HTML(email_message))
# Out:
# Hello,
# <p>
# Greetings from the BHTOM Automated Newsletter!
# </p>
# <p>
#
# </p>
# <p>
# As of 2024-06-04 05:26:33.080591+00:00, these are the new targets added in the last week with importance greater than 1, sorted by magnitude:
# </p>
# <p>
# <table border="0" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>ra</th>
#       <th>dec</th>
#       <th>mag_last</th>
#       <th>sun_separation</th>
#       <th>classification</th>
#       <th>description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/ZTF23aaqazhf/">ZTF23aaqazhf</a></td>
#       <td>285.385319</td>
#       <td>22.614975</td>
#       <td>15.9</td>
#       <td>125.0</td>
#       <td>Unknown</td>
#       <td>potential microlensing event from FINK, KATS24K002</td>
#     </tr>
#   </tbody>
# </table>
# </p>
# <p>
# In addition, here are some older targets that are currently visible and requested for observations. These targets have an importance greater than 4, a sun separation greater than 70, and a magnitude less than 18. They are also sorted by magnitude.
# </p>
# <hr>
# <p>
# <b><a href="https://bh-tom2.astrolabs.pl/targets/?type=&name=&classification=&description=&cone_search=&targetlist__name=&target_cone_search=&ra_min=&ra_max=&dec_min=0&dec_max=&gall_min=&gall_max=&galb_min=&galb_max=&importance_min=4&importance_max=&priority_min=&priority_max=&sun_min=70&sun_max=&mag_min=&mag_max=18&order=mag_last">North (dec>0):</a></b>
# <br>
# <table border="0" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>ra</th>
#       <th>dec</th>
#       <th>mag_last</th>
#       <th>sun_separation</th>
#       <th>classification</th>
#       <th>description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/TCrB/">TCrB</a></td>
#       <td>239.875676</td>
#       <td>25.920170</td>
#       <td>10.9</td>
#       <td>130.0</td>
#       <td>Nova</td>
#       <td>recurent nova predicted to explode 2024/2025</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/4U2206+54/">4U2206+54</a></td>
#       <td>331.984320</td>
#       <td>54.518447</td>
#       <td>11.3</td>
#       <td>78.0</td>
#       <td>XRB</td>
#       <td>Be X-ray binary</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia24ayd/">Gaia24ayd</a></td>
#       <td>300.825090</td>
#       <td>30.651260</td>
#       <td>12.9</td>
#       <td>109.0</td>
#       <td>Unknown</td>
#       <td>bright candidate for microlensing event</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/SAXJ2103.5+4545/">SAXJ2103.5+4545</a></td>
#       <td>315.898792</td>
#       <td>45.751547</td>
#       <td>13.7</td>
#       <td>91.0</td>
#       <td>XRB</td>
#       <td>Be X-ray binary</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/IGRJ21343+4738/">IGRJ21343+4738</a></td>
#       <td>323.584883</td>
#       <td>47.633391</td>
#       <td>14.0</td>
#       <td>85.0</td>
#       <td>XRB</td>
#       <td>Be X-ray binary</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/KS1947+300/">KS1947+300</a></td>
#       <td>297.397850</td>
#       <td>30.208827</td>
#       <td>14.1</td>
#       <td>112.0</td>
#       <td>XRB</td>
#       <td>Be X-ray binary</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/GROJ2058+42/">GROJ2058+42</a></td>
#       <td>314.698071</td>
#       <td>41.776995</td>
#       <td>14.3</td>
#       <td>94.0</td>
#       <td>XRB</td>
#       <td>Be X-ray binary</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/SN 2024igg/">SN 2024igg</a></td>
#       <td>227.378793</td>
#       <td>54.505622</td>
#       <td>14.6</td>
#       <td>100.0</td>
#       <td>SN</td>
#       <td>Astro-COLIBRI target</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia24azc/">Gaia24azc</a></td>
#       <td>296.202220</td>
#       <td>23.630800</td>
#       <td>14.8</td>
#       <td>117.0</td>
#       <td>Unknown</td>
#       <td>bright gal.plane source candidate microlensing event or Be-type outburst</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia24alm/">Gaia24alm</a></td>
#       <td>341.329830</td>
#       <td>60.919100</td>
#       <td>15.4</td>
#       <td>71.0</td>
#       <td>Unknown</td>
#       <td>candidate bright microlensing event on the rise or Be star</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/NGC5683-Seyfert/">NGC5683-Seyfert</a></td>
#       <td>218.718578</td>
#       <td>48.661870</td>
#       <td>15.7</td>
#       <td>103.0</td>
#       <td>AGN</td>
#       <td>active nucleus of a nearby galaxy for frequent monitoring</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia18bwz/">Gaia18bwz</a></td>
#       <td>174.611270</td>
#       <td>3.368310</td>
#       <td>15.7</td>
#       <td>100.0</td>
#       <td>CV</td>
#       <td>Known dwarf nova QZ Vir in outburst</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia24azi/">Gaia24azi</a></td>
#       <td>286.704270</td>
#       <td>15.009500</td>
#       <td>16.0</td>
#       <td>130.0</td>
#       <td>Microlensing Event</td>
#       <td>candidate microlensing event</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/ZTF18aarippg/">ZTF18aarippg</a></td>
#       <td>217.566838</td>
#       <td>23.062372</td>
#       <td>16.1</td>
#       <td>123.0</td>
#       <td>QSO</td>
#       <td>Tick-Tok possibly merging Super Massive Black Hole binary</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia23dfy/">Gaia23dfy</a></td>
#       <td>281.922640</td>
#       <td>9.043970</td>
#       <td>16.5</td>
#       <td>137.0</td>
#       <td>Unknown</td>
#       <td>candidate microlensing event</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia24bfe/">Gaia24bfe</a></td>
#       <td>311.334720</td>
#       <td>27.577440</td>
#       <td>16.6</td>
#       <td>104.0</td>
#       <td>Unknown</td>
#       <td>candidate microlensing event</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/AR UMa/">AR UMa</a></td>
#       <td>168.935790</td>
#       <td>42.972890</td>
#       <td>16.9</td>
#       <td>79.0</td>
#       <td>CV</td>
#       <td>None</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/SN 2024elf/">SN 2024elf</a></td>
#       <td>264.113343</td>
#       <td>39.965370</td>
#       <td>17.1</td>
#       <td>117.0</td>
#       <td>SN</td>
#       <td>Astro-COLIBRI target</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia23dgt/">Gaia23dgt</a></td>
#       <td>204.096070</td>
#       <td>25.538710</td>
#       <td>17.1</td>
#       <td>113.0</td>
#       <td>QSO</td>
#       <td>Brightening in Gaia source coincident with Seyfert I galaxy</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/SN2024gy/">SN2024gy</a></td>
#       <td>183.963708</td>
#       <td>13.115589</td>
#       <td>17.1</td>
#       <td>104.0</td>
#       <td>SN</td>
#       <td>classified SN Ia at 5Mpc</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia24adu/">Gaia24adu</a></td>
#       <td>205.400100</td>
#       <td>43.413980</td>
#       <td>17.4</td>
#       <td>101.0</td>
#       <td>Unknown</td>
#       <td>rise in a radio galaxy</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia24acn/">Gaia24acn</a></td>
#       <td>298.644780</td>
#       <td>30.361130</td>
#       <td>17.7</td>
#       <td>111.0</td>
#       <td>Unknown</td>
#       <td>Candidate binary microlensing event</td>
#     </tr>
#     <tr>
#       <td><a href="https://bh-tom2.astrolabs.pl/targets/Gaia24aup/">Gaia24aup</a></td>
#       <td>313.096720</td>
#       <td>57.055180</td>
#       <td>17.7</td>
#       <td>86.0</td>
#       <td>Unknown</td>
#       <td>candidate microlensing event</td>
#     </tr>
#   </tbody>
# </table>
# </p>
# <hr>
# <p>
# <b><a href="https://bh-tom2.astrolabs.pl/target

# %%
## from last week's targets - identify these with importance = 0 and inform observed to stop observing
# or: list targets where importance changed from >0 to 0 in the last week - how to trace it ??
# history of importance?
